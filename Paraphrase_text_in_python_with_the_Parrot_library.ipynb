# %% [markdown]
# <a href="https://colab.research.google.com/github/drm1072/Workload-DRM/blob/main/Paraphrase_text_in_python_with_the_Parrot_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How to Paraphrase text in Python with PARROT**

# %%
! pip install git+https://github.com/PrithivirajDamodaran/Parrot.git
# Out:
# ...
#   Cloning https://github.com/PrithivirajDamodaran/Parrot.git to /tmp/pip-req-build-uvuk955g
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Parrot.git /tmp/pip-req-build-uvuk955g
# ...
#      |████████████████████████████████| 2.3MB 13.8MB/s
# ...
#      |████████████████████████████████| 1.2MB 42.0MB/s
# ...
#      |████████████████████████████████| 51kB 6.1MB/s
# ...
#      |████████████████████████████████| 81kB 9.0MB/s
# ...
#      |████████████████████████████████| 901kB 63.0MB/s
# ...
#      |████████████████████████████████| 3.3MB 49.0MB/s
# ...
#   Created wheel for parrot: filename=parrot-1.0-cp37-none-any.whl size=8698 sha256=23f26fa2c1f19b5e4177ddb878cb6b4d052155166094330a0df0931995f1e12a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p5igq_d2/wheels/96/16/2c/b241910909ea2fc05552298ed25a2b1383f369c672f8aee255
# ...

# %%
# Import libraries
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
# For reproducibility
def random_state(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

random_state(1234)

# %%
#Init models (make sure you init ONLY once if you integrate this to your code)
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)

# %%
phrases = ["What's the most delicious Watermelon?, "]

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  What's the most delicious Watermelon?,
# ----------------------------------------------------------------------------------------------------
# ('can you list the best watermelon flavours?', 37)
# ('what is a really amazing watermelon?', 30)
# ("what's the most delicious watermelon you've ever eaten?", 30)
# ('list the most delicious watermelon varieties?', 27)
# ('recommend some of the most delicious watermelon recipes?', 26)
# ('which is the most delicious watermelon ever?', 21)
# ('recommend some of the most delicious watermelon?', 18)
# ('tell me the most delicious watermelon?', 18)
# ('can you list the most delicious watermelons?', 17)
